# %% [markdown]
# ![updated-banner.png](data:image/png;base64,...)

# %% [markdown]
# # Lab 1 - Intro to Notebooks
# Welcome to your first lab notebook for CMPUT 191 - *Introduction to Data Science*!
#
# ### Today's Lab:
# In today's lab, you'll learn how to:
#
# 1.   navigate Jupyter notebooks (like this one);
# 2.   write and evaluate some basic expressions in Python, the computer language of the course;
#
# This lab covers parts of Chapter 3 of the online textbook. You should read the examples in the book, but not right now. Instead, let's get started! And of course, feel free to reference back to class materials or the demo videos as you go. We'll start to touch on some Python basics, which we'll go back over again in tomorrow's lecture, so consider this a great head start!
#
# Below, you'll find a variety of numbered sections that articulate each part of the lab, and within them, you'll find the questions in the assignment (bolded in red text) that you have to answer before you upload the notebook file to eClass to be graded. Instructions to properly submit your assignment will be included at the bottom of the file, so please carefully read through the entire file, and feel free to ask questions!

# %% [markdown]
# # 1. Google Colab and Jupyter Notebooks
# This document is called a Jupyter notebook. A notebook is a place to write programs and view their results, and also to write text. They are super handy for the manipulation and presentation of data, which is what data science is all about!
#
# You'll be viewing and working on your Jupyter Notebook files inside a web application called Google Colab -- think of it like Google Docs, but for these special notebook files. It all integrates into your exisiting Google Drive setup quite nicely, and your files get automatically saved too.
#
# There are two key components to Notebook files:

# %% [markdown]
# ## 1.1. Text cells
# In a notebook, each rectangle containing text or code is called a *cell*.
#
# Text cells (like this one) can be edited by double-clicking on them. They're written in a simple format called [Markdown](http://daringfireball.net/projects/markdown/syntax) to add formatting and section headings.  You don't need to learn Markdown, but you might want to. We've also made a handy tutorial video on some Markdown basics, if you're curious!
#
# Google Colab provides a really nice toolbar that helps you format your text if learning the Markdown basics isn't quite your style. The toolbar looks like this, and can help you change font size, style, insert images, lists, emojis, and more:
#
# ![image.png](data:image/png;base64,...)
#
# After you edit a text cell and are done with your changes, there are two ways you can confirm them:
#
# 1.   hold down `shift` + `return` (Mac) or `shift` + `enter` (Windows/Linux).
# 2.   click the "Close Markdown Editor" button in the Google Colab cell options pane, which looks like a pencil with a cross through it in the toolbar hovering over each cell:
#
# ![Screen Shot 2022-09-01 at 12.19.53 PM.png](data:image/png;base64,...)
#
# With that in mind, try not to delete the instructions of the lab!)

# %% [markdown]
# <font color='red'>**Question 1.1.1.**</font> This paragraph is in its own text cell.  Try editing it so that this sentence is the last sentence in the paragraph, and then save your changes. This sentence, for example, should be deleted.  So should this one.

# %% [markdown]
# ## 1.2. Code cells
# The other kind of cells we see contain code in the Python 3 programming language. Running a code cell will execute, or run, all of the code it contains.
#
# To run the code in a code cell, first mouse over the cell in Google Colab, or click on it, to bring it into focus. A play button will appear to the left of the cell, and all you have to do it click on it to fire off the code! The icon will look like this:
#
# ![Screen Shot 2022-09-01 at 12.26.36 PM.png](data:image/png;base64,...)
#
# Try running this cell:

# %%
print("Hello, World!")

# %% [markdown]
# And this one:

# %%
print("\N{WAVING HAND SIGN}, \N{EARTH GLOBE ASIA-AUSTRALIA}!")

# %% [markdown]
# The fundamental building block of Python code is an expression. Cells can contain multiple lines with multiple expressions. When you run a cell, the lines of code are executed in the order in which they appear. Every `print` expression prints a line. Run the next cell and notice the order of the output.

# %%
print("First this line is printed,")
print("and then this one.")

# %% [markdown]
# <font color='red'>**Question 1.2.1.**</font> Change the cell above so that it prints out:
#
#     First this line,
#     then the whole 🌏,
#     and then this one.
#
# *Hint:* If you're stuck on the Earth symbol for more than a few minutes, try talking to a neighbor or a TA. That's a good idea for any lab problem.

# %% [markdown]
# ## 1.3. Writing Jupyter notebooks
# You can use Jupyter notebooks for your own projects or documents.  When you make your own notebook, you'll need to create new cells for text and code.
#
# To add a cell, in the menu bar at the top of the screen, underneath the notebook title and the *File, Edit, View...* toolbar, you'll see buttons `+ Code` and `+ Text` to create cells of either type at the bottom of the notebook. Additionally, in the floating cell options pane (where you saw Close Markdown Editor button), you'll also see up and down arrows, where you can reorder the cells in your notebook file by moving them up and down respectively.
#
# <font color='red'>**Question 1.3.1.**</font> Add a code cell below this one.  Write code in it that prints out:
#
#     A whole new cell! ♪🌏♪
#
# (That musical note symbol is like the Earth symbol.  Its long-form name is `\N{EIGHTH NOTE}`.)
#
# Run your cell to verify that it works.

# %% [markdown]
# ## 1.4. Errors
# Python is a language, and like natural human languages, it has rules.  It differs from natural language in two important ways:
# 1. The rules are *simple*.  You can learn most of them in a few weeks and gain reasonable proficiency with the language in a semester.
# 2. The rules are *rigid*.  If you're proficient in a natural language, you can understand a non-proficient speaker, glossing over small mistakes.  A computer running Python code is not smart enough to do that.
#
# Whenever you write code, you'll make mistakes.  When you run a code cell that has errors, Python will sometimes produce error messages to tell you what you did wrong.
#
# Errors are okay; even experienced programmers make many errors.  When you make an error, you just have to find the source of the problem, fix it, and move on.
#
# We have made an error in the next cell.  Run it and see what happens. And in the cell after that, run it, and notice what was changed to fix it! Sometime, Google Colab will even underline code issues with a red squiggly line, similar to spell check, when it can detect it ahead of time.

# %%
print("This line is missing something."

# %%
print("This line is missing something.")

# %% [markdown]
# **Note:** In the toolbar, there is the option to click `Runtime > Run all`, which will run all the code cells in this notebook in order. However, the notebook stops running code cells if it hits an error, like the one in the cell above.

# %% [markdown]
# You should see something like this:
#
# ![image.png](data:image/png;base64,...)
#
# The last line of the error output attempts to tell you what went wrong.  The *syntax* of a language is its structure, and this `SyntaxError` tells you that you have created an illegal structure.  "`EOF`" means "end of file," so the message is saying Python expected you to write something more (in this case, a right parenthesis) before finishing the cell.
#
# There's a lot of terminology in programming languages, but you don't need to know it all in order to program effectively. Use your resources! Search for the error in online documentation or ask a TA for some hints.
#
# Try to fix the code above so that you can run the cell and see the intended message instead of an error.

# %% [markdown]
# ## 1.5. The Runtime
# The runtime is a program that executes the code inside your notebook and outputs the results. Next to each cell, you'll see a circular progress indicator next to a cell that you've clicked play on to see if the runtime is busy working on running your code.
#
# Next to every code cell that you've already run, where you'd normally see the play button but once you move your mouse away, you'll see square brackets with a number, like `[1]`. Effectively, that keeps track of the order in which your cells were run. Later on in the course (and a little bit further down in this notebook), you'll learn about variables, and with that concept, it's important to pay attention to the order in which cells were run -- but we'll touch on more of that later.
#
# Additionally, in the toolbar at the top of the screen, you can monitor the RAM and Disk usage of the current notebook file -- this shouldn't ever be of concern, but in case you write or run some code that's taking way too long, and eating up available resources, you can select `Runtime > Restart runtime` in the toolbar to stop any code from running.

# %% [markdown]
# ##1.6 Making sure you see it all!
# Sometimes, Google Colab might not initially display all of the cells in the notebook -- but that proves a bit of an issue considering we need to see the whole story to make sure you get all your questions answered in an assignment!
#
# In Google Colab, the keyboard shortcut `cmd` + `[` (Mac) or `ctrl` + `[` (Windows/Linux) will exapnd all the cells in the notebook to be visible. Additionally, we'll always keep a small rubric at the bottom of each lab assignment -- so that you can go over it yourself and make sure you were able to tick every question off your list.

# %% [markdown]
# <font color='red'>**Question 1.6.1.**</font>  Add a text cell below this with  a declaritive statement that says something along the lines of "I'll be sure to expand all the cells in my notebook and double check with each lab's rubric to make sure I didn't miss a question!". Or something similar will do.

# %% [markdown]
# ## 1.7. Submitting your work
# All lab and course assignments in the course will be distributed as notebooks like this one, and to sumbit, you'll select `File > Download > Download .ipynb` in the toolbar, and sumbit the file that it downloads to a submission page on eClass for the given week. Like we said earlier, notebooks will be automatically saved to your Google Drive -- but that won't be sufficient for submission. You'll be responsible for submitting your notebook files to the proper portal on eClass ahead of each deadline. And don't fret -- if you have any questions about doing this step properly, feel free to reach out to any of the teaching team.

# %% [markdown]
# # 2. Types
#
# Everything part of each expression or statement has a type in Python. The type influences what can and cannot be done with a particular object in your code. You can even create your own types, if you're so inclined! To find out what type something is you can use the `type()` function. And if this all seems a little fuzzy still -- we'll be talking about it again in the lecture tomorrow, so consider this a good head start.

# %%
type(42)

# %% [markdown]
# ## 2.1 Numbers
#
# An `int` (short for integer) is the same thing you know from good ol' math. It's a whole number (meaning with no decimal), and it can be positive or negative.
#
# Quantitative (meaning dealing with numbers) information arises everywhere in data science. In addition to representing commands to print out lines, expressions can represent numbers and methods of combining numbers. The expression `3.2500` evaluates to the number 3.25. (Run the cell and see.)

# %%
3.2500

# %% [markdown]
# Notice that we didn't have to `print`. When you run a notebook cell, if the last expression written has a value, then Google Colab helpfully prints out that value for you. However, it won't print out prior lines automatically. Feel free to test this out!

# %%
type(3.25)

# %% [markdown]
# `float` is the other kind of number type we might see. This is, in contrast to an `int`, is simply a number that _has_ a decimal.

# %%
print(2)
3
4

# %% [markdown]
# Above, you should see that 4 is the value of the last expression, 2 is printed, but 3 is lost forever because it was neither printed nor last.
#
# You don't want to print everything all the time anyway.  But if you feel sorry for 3, change the cell above to print it.

# %% [markdown]
# ## 2.2. Arithmetic
# Python makes for a really robust and easy to use calculator as well! For example, the line in the next cell subtracts.  Its value is what you'd expect.  Run it, to double check!

# %%
3.25 - 1.5

# %% [markdown]
# Many basic arithmetic operations are built into Python.  The textbook section on [Expressions](http://www.inferentialthinking.com/chapters/03/1/expressions.html) describes all the arithmetic operators used in the course.  Addition and subtraction are pretty straightfoward, using the `+` and `-` operators. Furthermore, multiplication and division are done by using the `*` and `/` operators respectively.
#
# The operator that differs most from typical math notation is `**`, which raises one number to the power of the other. So, `2**3` stands for $2^3$ and evaluates to 8.
#
# The order of operations is the same as what you learned in elementary school, and Python also has parentheses.  For example, compare the outputs of the cells below. The second cell uses parentheses to net us a year we're quite familiar with by now!

# %%
3+6*5-6*3**2*2**3/4*7+1

# %%
4+(6*5-(6*3))**2*((2**3)/4*7)+1

# %% [markdown]
# In standard math notation, the first expression is
#
# $$3 + 6 \times 5 - 6 \times 3^2 \times \frac{2^3}{4} \times 7 + 1,$$
#
# while the second expression is
#
# $$3 + (6 \times 5 - (6 \times 3))^2 \times (\frac{(2^3)}{4} \times 7) + 1.$$
#
# <font color='red'>**Question 2.2.1.**</font> Write a Python expression in this next cell that's equal to $5 \times (3 \frac{10}{11}) - 50 \frac{1}{3} + 2^{.5 \times 22} - \frac{7}{33} + 5$.  That's five times three and ten elevenths, minus fifty and a third, plus two to the power of half twenty-two, minus seven thirty-thirds plus three.  By "$3 \frac{10}{11}$" we mean $3+\frac{10}{11}$, not $3 \times \frac{10}{11}$.
#
# Replace the ellipses below (`...`) with your expression.  Try to use parentheses only when necessary.
#
# *Hint:* The correct output should start with a familiar number.

# %%
...

# %% [markdown]
# # 3. Variables
# In natural language, we have terminology that lets us quickly reference very complicated concepts.  We don't say, "That's a large mammal with brown fur, sharp teeth, and big eyes running !"  Instead, we just say, "Bear!"
#
# In Python, we do this with *assignment statements*. An assignment statement has a name on the left side of an `=` sign and an expression to be evaluated on the right.

# %%
ten = 3 * 2 + 4

# %% [markdown]
# When you run that cell, Python first computes the value of the expression on the right-hand side, `3 * 2 + 4`, which is the number 10.  Then it assigns that value to the name `ten`.  At that point, the code in the cell is done running.
#
# After you run that cell, the value 10 is bound to the name `ten`:

# %%
ten

# %% [markdown]
# The statement `ten = 3 * 2 + 4` is not asserting that `ten` is already equal to `3 * 2 + 4`, as we might expect by analogy with math notation.  Rather, that line of code changes what `ten` means; it now refers to the value 10, whereas before it meant nothing at all.
#
# If the designers of Python had been ruthlessly pedantic, they might have made us write:
#
#     define the name ten to hereafter have the value of 3 * 2 + 4
#
# instead.  You will probably appreciate the brevity of "`=`"!  But keep in mind that this is the real meaning.
#
# Try writing code that uses a name (like `eleven`) that hasn't been assigned to anything.  You'll see an error!

# %%
...

# %% [markdown]
# Until now we've been using variables to store some sort of calculation, but of course variables can be used in these calculations. Perform an operation on the variable `ten` to ouput the number 15.

# %%
...

# %% [markdown]
# A common practice in Jupyter notebooks is to assign a value to a name and then immediately evaluate the name in the last line in the cell so that the value is displayed as output.

# %%
close_to_pi = 355/113
close_to_pi

# %% [markdown]
# Another common practice is that a series of lines in a single cell will build up a complex computation in stages, naming the intermediate results.

# %%
semimonthly_salary = 841.25
monthly_salary = 2 * semimonthly_salary
number_of_months_in_a_year = 12
yearly_salary = number_of_months_in_a_year * monthly_salary
yearly_salary

# %% [markdown]
# Names in Python can have letters (upper- and lower-case letters are both okay and count as different letters), underscores, and numbers.  The first character can't be a number, however (otherwise a name might look like a number).  And names can't contain spaces, since spaces are used to separate pieces of code from each other.
#
# Other than those rules, what you name something doesn't matter *to Python*.  For example, this cell does the same thing as the above cell, except everything has a different name:

# %%
a = 841.25
b = 2 * a
c = 12
d = c * b
d

# %% [markdown]
# **That said**, names are very important for making your code *readable* to yourself and others.  The cell above is shorter, but it's totally useless without an explanation of what it does.

# %% [markdown]
# ## 3.1. Comments
# There's actually another way to keep your code *readable* without having to rely on just your variable names, and they're called comments, which look like:
#
#     # This is a comment
#     # This is another comment
#     # Wow, I have so many comments!
#
# This is called a *comment*. It doesn't make anything happen in Python; Python ignores anything on a line after a `#`.  Instead, it's there to communicate something about the code to you, the human reader. Comments are extremely useful.
#
#
# <img src="http://imgs.xkcd.com/comics/future_self.png">
# Source: http://imgs.xkcd.com/comics/future_self.png

# %% [markdown]
# ## 3.2. Application: A physics experiment
#
# On the Apollo 15 mission to the Moon, astronaut David Scott famously replicated Galileo's physics experiment in which he showed that gravity accelerates objects of different mass at the same rate. Because there is no air resistance for a falling object on the surface of the Moon, even two objects with very different masses and densities should fall at the same rate. David Scott compared a feather and a hammer.
#
# You can run the following cell to watch a video of the experiment.

# %%
from IPython.display import YouTubeVideo
# The original URL is: 
#https://www.youtube.com/watch?v=U7db6ZeLR5s

YouTubeVideo("U7db6ZeLR5s")

# %% [markdown]
# Here's the transcript of the video:
#
# **167:22:06 Scott**: Well, in my left hand, I have a feather; in my right hand, a hammer. And I guess one of the reasons we got here today was because of a gentleman named Galileo, a long time ago, who made a rather significant discovery about falling objects in gravity fields. And we thought where would be a better place to confirm his findings than on the Moon. And so we thought we'd try it here for you. The feather happens to be, appropriately, a falcon feather for our Falcon. And I'll drop the two of them here and, hopefully, they'll hit the ground at the same time.
#
# **167:22:43 Scott**: How about that!
#
# **167:22:45 Allen**: How about that! (Applause in Houston)
#
# **167:22:46 Scott**: Which proves that Mr. Galileo was correct in his findings.

# %% [markdown]
# **Newton's Law.** Using this footage, we can also attempt to confirm another famous bit of physics: Newton's law of universal gravitation. Newton's laws predict that any object dropped near the surface of the Moon should fall
#
# $$\frac{1}{2} G \frac{M}{R^2} t^2 \text{ meters}$$
#
# after $t$ seconds, where $G$ is a universal constant, $M$ is the moon's mass in kilograms, and $R$ is the moon's radius in meters.  So if we know $G$, $M$, and $R$, then Newton's laws let us predict how far an object will fall over any amount of time.
#
# To verify the accuracy of this law, we will calculate the difference between the predicted distance the hammer drops and the actual distance.  (If they are different, it might be because Newton's laws are wrong, or because our measurements are imprecise, or because there are other factors affecting the hammer for which we haven't accounted.)
#
# Someone studied the video and estimated that the hammer was dropped 113 cm from the surface. Counting frames in the video, the hammer falls for 1.2 seconds (36 frames).

# %% [markdown]
# <font color='red'>**Question 3.2.1.**</font> Complete the code in the next cell to fill in the data from the experiment.
#
# *Hint:* No computation required; just fill in data from the paragraph above.

# %%
# t, the duration of the fall in the experiment, in seconds.
# Fill this in.
time = ...

# The estimated distance the hammer actually fell, in meters.
# Fill this in.
estimated_distance_m = ...

# %% [markdown]
# <font color='red'>**Question 3.2.2.**</font> Now, complete the code in the next cell to compute the difference between the predicted and estimated distances (in meters) that the hammer fell in this experiment.
#
# This just means translating the formula above ($\frac{1}{2}G\frac{M}{R^2}t^2$) into Python code.  You'll have to replace each variable in the math formula with the name we gave that number in Python code.
#
# *Hint:* Try to use variables you've already defined in **Question 3.3.1**
#
# <!--
# BEGIN QUESTION
# name: q3_3_2
# -->

# %%
# First, we've written down the values of the 3 universal constants 
# that show up in Newton's formula.

# G, the universal constant measuring the strength of gravity.
gravity_constant = 6.674 * 10**-11 

# M, the moon's mass, in kilograms.
moon_mass_kg = 7.34767309 * 10**22 

# R, the radius of the moon, in meters.
moon_radius_m = 1.737 * 10**6 

# The distance the hammer should have fallen 
# over the duration of the fall, in meters, 
# according to Newton's law of gravity.  
# The text above describes the formula
# for this distance given by Newton's law.
# **YOU FILL THIS PART IN.**
predicted_distance_m = ...

# Here we've computed the difference 
# between the predicted fall distance and the distance we actually measured.
# If you've filled in the above code, this should just work.
difference = predicted_distance_m - estimated_distance_m
difference

# %% [markdown]
# ## Rubric
# Use the rubric below to make sure you caught every question in the notebook.
#
# | Question     |          Summary           | Points  |
# |--------------|----------------------------|--|
# |Question 1.1.1|Editing a text cell.        |/1|
# |Question 1.2.1|Editing a code cell.        |/1|
# |Question 1.3.1|Adding a new cell           |/1|
# |Question 1.6.1|Understanding cell exapnsion|/1|
# |Question 2.2.1|Doing some math             |/1|
# |Question 3.2.1|Filling in some variables   |/1|
# |Question 3.2.2|Using variables in practice |/1|

# %% [markdown]
# ## Submission
#
# And just like that, you've made it to the end of your first CMPUT 191 lab! Make sure you have run all cells in your notebook in order before downloading your submission, so that everything required appears in the output.

# %% [markdown]
# In the cell below this, be sure to add your name and CCID to the cell so the notebook can be easily identified back to you. In future notebooks, we'll have you do this as the very first task -- but today, we had to show you how to edit a text cell firstly afterall!

# %% [markdown]
# **Name:**
#
# **CCID:**

# %% [markdown]
# Remember to go to `File > Download > Download .ipynb` to download your completed notebook file. After doing so, you'll have to rename your notebook file to the following format:
# `{YOUR CCID HERE}_lab1.ipynb` (_without_ the curly brackets!)
#
# For example, if my CCID was `jsmith`, I would rename my file to `jsmith_lab1.ipynb` before uploading my notebook. If your notebook file is incorrectly named, we may run into trouble correctly marking it, and you risk losing points as a result.
#
# Once all that is taken care of, you're good to upload your notebook file to the portal on eClass -- and make sure you do so ahead of the deadline!
